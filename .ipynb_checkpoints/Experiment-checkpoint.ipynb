# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib as tb
from talib import stream
import mplfinance as mpf

from data_utils.get_data import *

from indicators.indicators import *
from indicators.custom_indicators import *
# %matplotlib inline

# %%
acq_window = 500
reg_window = 75
reg_mean = 10
deviation = 0.8 / 100

#Price to apply indicators on
price_col = 'Close'

# %%
path = './data/csv/EURUSD60.csv'

rates = load_frames(path)
rates.tail()
rates = rates[-acq_window:]

# %%
# %%capture
keys = reg_envelopes(rates, price_col ,deviation,reg_window,reg_mean)

# %%
addp = mpf.make_addplot(rates[keys])
mpf.plot(rates, type='candle', volume = True,addplot = addp, style = 'yahoo',show_nontrading = False)

# %% [raw]
# X_buy, Y_cls_buy, Y_reg_buy, X_sell, Y_cls_sell, Y_reg_sell, X_hold, Y_cls_hold, Y_reg_hold = generate_data(rates,
#                                                             r = 1,
#                                                             test = False,
#                                                             save_img = True,
#                                                             tp = 0.00500,
#                                                             sl = 0.00250,
#                                                             sl_h = 0.00150,
#                                                             window_range_back = 30,
#                                                             window_range_front = 15)
